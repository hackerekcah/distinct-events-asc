# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload 2

# %%
from utils.wrapper import ArgWrapper

# %%
from main import run
args= ArgWrapper(
    exp='CNN_MTS_MIL', 
    net='CNN_MTS_MIL',
    batch_size=256,
    ckpt_prefix='Run01',
    device='5',
    combine_type='conv1d',
    pooling='max',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=50,
    seed=0
)

# %%
for i in range(10):
    args['ckpt_prefix'] = 'Run0' + str(i+1)
    args['seed'] = i + 1
    run(args)
# Out:
# [CheckPoint:]Epoch49,acc not improved on 0.676
# [CheckPoint:]saved model to /data/songhongwei/proj/distinct_events_asc/ckpt/CNN_MTS_MIL/Run010,CNN_MTS_MIL,Epoch_49,acc_0.663622.tar
