# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload 2

# %%
# %env CUDA_VISIBLE_DEVICES 5
# Out:
# env: CUDA_VISIBLE_DEVICES=5

# %%
from utils.vis import MILVis
from net_archs import CNN_MTS2
from utils.wrapper import ArgWrapper
model = CNN_MTS2(
    args=ArgWrapper(net='CNN_MTS', pooling='max', dropout=0.0, sub_concept=4, is_instance_softmax=True, combine_type='conv1d', nb_class=10, out_sigmoid=True)
)

# %%
vis = MILVis('../ckpt/CNN_MTS_MD_4/Run03,CNN_MTS,Epoch_32,acc_0.702542.tar', model=model)
# Out:
# 10080it [00:00, 216625.51it/s]

# %%
vis.dump_result(mode='train')
# Out:
# [LOGGING]: Loading train a of shape:  (6122, 64, 400)
# [LOGGING] Normalize using device a
# result file pickle to ../ckpt/FC_lin/Run01,FullConv,Epoch_6,acc_0.665608_train_result.pkl

# %%
vis.dump_result(mode='test')
# Out:
# [LOGGING]: Loading test a of shape:  (2518, 64, 400)
# [LOGGING] Normalize using device a
# result file pickle to ../ckpt/FC_lin/Run01,FullConv,Epoch_6,acc_0.665608_test_result.pkl

# %%
vis.show('public_square-london-250-7474-a.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
vis.confusion()
# Out:
# [LOGGING]: Loading test a of shape:  (2518, 40, 500)
# [LOGGING] Normalize using device a
# /home/songhongwei/anaconda2/envs/asc_mt/lib/python3.6/site-packages/scipy/io/matlab/miobase.py:414: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   arr[empties] = ' '
