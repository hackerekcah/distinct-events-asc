# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload 2

# %%
from utils.wrapper import ArgWrapper

# %%
from main import run
args= ArgWrapper(
    exp='CNN_MIL', 
    net='CNN_MIL',
    batch_size=256,
    ckpt_prefix='Run01',
    device='3',
    pooling='max',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=50,
    seed=0
)

# %%
for i in range(10):
    args['ckpt_prefix'] = 'Run0' + str(i+1)
    args['seed'] = i + 1
    run(args)
# Out:
# [CheckPoint:]Epoch49,acc not improved on 0.642
# [CheckPoint:]saved model to /data/songhongwei/proj/distinct_events_asc/ckpt/CNN_MIL/Run010,CNN_MIL,Epoch_49,acc_0.634234.tar
